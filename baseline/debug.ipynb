# %%
import pandas as pd

user_feat_df = pd.read_csv("../data/A2-Rec/user.csv")

for column_name in user_feat_df.columns:
    print(column_name, user_feat_df[column_name].max())

item_feat_df = pd.read_csv("../data/A2-Rec/item.csv")

for column_name in item_feat_df.columns:
    print(column_name, item_feat_df[column_name].max())
# Out:
# uid u050000
# u_cat_01 66
# u_cat_02 2
# u_cat_03 6
# u_cat_04 31
# u_cat_05 6
# u_cat_06 3
# u_cat_07 5
# u_cat_08 2
# iid i002156
# i_cat_01 6
# i_cat_02 24
# i_cat_03 93
# i_bucket_01 7
