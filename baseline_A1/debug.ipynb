# %%
import numpy as np

# %%
A1 = np.load("../data/A1-Cls/A1.npz")

# %%
A1['attr_shape']
# Out:
# array([13752,   767])

# %%
A1['attr_shape']
# Out:
# array([13752,   767])

# %%
A1['attr_data'].shape
# Out:
# (1880637,)

# %%
for key in A1.keys():
    print(key)
# Out:
# adj_data
# adj_indices
# adj_indptr
# adj_shape
# attr_data
# attr_indices
# attr_indptr
# attr_shape
# labels
# train_idx
# test_idx
